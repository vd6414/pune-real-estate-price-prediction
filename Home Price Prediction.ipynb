# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Price_data.csv")

# %%
df.head()
# Out:
#    Area_Name  BHK  Amenities_Count  Balcony_Count  Market_Distance_KM  \
# 0          1    4               15              2                 3.2
# 1          1    1               20              4                 2.6
# 2          1    2               14              2                 0.9
# 3          1    2                8              3                 4.6
# 4          1    2                7              2                 2.0
#
#    Building_Age  Floor_Number  Parking_Spaces  Bathrooms  Area  \
# 0             5            34               1          3  1265
# 1            19            22               1          1  1510
# 2            20            22               1          2   998
# 3            20            11               3          2   609
# 4            17            25               1          1  3481
#
#    Ready_To_Move_In_Months     Price
# 0                       19  26146498
# 1                        9  20699816
# 2                       17  19283296
# ...

# %%
df.columns
# Out:
# Index(['Area_Name', 'BHK', 'Amenities_Count', 'Balcony_Count',
#        'Market_Distance_KM', 'Building_Age', 'Floor_Number', 'Parking_Spaces',
#        'Bathrooms', 'Area', 'Ready_To_Move_In_Months', 'Price'],
#       dtype='object')

# %%
X = df[['Area_Name', 'BHK', 'Amenities_Count', 'Balcony_Count',
       'Market_Distance_KM', 'Building_Age', 'Floor_Number', 'Parking_Spaces',
       'Bathrooms', 'Area', 'Ready_To_Move_In_Months']]
Y = df['Price']

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X ,Y , train_size = 0.8 , random_state = 88)

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
Area_Names = { 1:'Akurdi', 2:'Balewadi', 3:'Baner', 4:'Bavdhan', 5:'Hadpsar', 
               6:'Hinjawadi', 7:'Khadki', 8:'Kharadi',9:'Kiwale', 10:'Kothrud', 
               11:'Pimpri', 12:'Ravet', 13:'Talegaon Dabhade', 14:'Wakad' }
print(Area_Names)


a = int(input("\nEnter your Area Name:"))
b = int(input("Enter Bedroom Count:"))
c = int(input("Enter Amenities_Count:"))
d = int(input("Enter Balcony_Count:"))
e = int(input("Enter Market_Distance_KM:"))
f = int(input("Enter Building_Age:"))
g = int(input("Enter Floor_Number:"))
h = int(input("Enter Parking_Spaces:"))
i = int(input("Enter Bathrooms count:"))
j = int(input("Enter Area in sqft:"))
k = int(input("Enter Ready_To_Move_In_Months:"))

price = model.predict([[a,b,c,d,e,f,g,h,i,j,k]])

print(f"\nThe predicted market price for a {b} BHK flat in {Area_Names[a]} with a carpet area of {j} sq.ft on floor {g} is \033[1m₹{price}\033[0m.")
# Out:
# {1: 'Akurdi', 2: 'Balewadi', 3: 'Baner', 4: 'Bavdhan', 5: 'Hadpsar', 6: 'Hinjawadi', 7: 'Khadki', 8: 'Kharadi', 9: 'Kiwale', 10: 'Kothrud', 11: 'Pimpri', 12: 'Ravet', 13: 'Talegaon Dabhade', 14: 'Wakad'}
# Enter your Area Name: 2
# Enter Bedroom Count: 3
# Enter Amenities_Count: 5
# Enter Balcony_Count: 6
# Enter Market_Distance_KM: 5
# Enter Building_Age: 5
# Enter Floor_Number: 2
# Enter Parking_Spaces: 2
# Enter Bathrooms count: 3
# Enter Area in sqft: 6
# Enter Ready_To_Move_In_Months: 3
# The predicted market price for a 3 BHK flat in Balewadi with a carpet area of 6 sq.ft on floor 2 is ₹[18678419.06364166].
